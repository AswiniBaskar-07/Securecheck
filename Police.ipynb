# %%
import pandas as pd

# %%
import numpy as np

# %%
#Read the CSV file
df=pd.read_csv(r"C:\Users\BaBuReDdI\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")
# Out:
# C:\Users\BaBuReDdI\AppData\Local\Temp\ipykernel_13028\309057140.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\BaBuReDdI\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")

# %%
#Check data
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(21720)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
# Fill missing values
print(df['search_type'].value_counts())
# Out:
# search_type
# Frisk             21971
# Vehicle Search    21847
# Name: count, dtype: int64

# %%
choices = ['Frisk', 'Vehicle Search ']

# %%
df.loc[df['search_type'].isna(), 'search_type'] = np.random.choice(
    choices,
    size=df['search_type'].isna().sum()
)

# %%
#To check missing values
df.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Convert date and time
df['stop_date'] = pd.to_datetime(df['stop_date'])
df['stop_time'] = pd.to_datetime(df['stop_time'])
# Out:
# C:\Users\BaBuReDdI\AppData\Local\Temp\ipykernel_13028\792788991.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['stop_time'] = pd.to_datetime(df['stop_time'])

# %%
df
# Out:
#        stop_date           stop_time country_name driver_gender  \
# 0     2020-01-01 2025-10-23 00:00:00       Canada             M
# 1     2020-01-01 2025-10-23 00:01:00        India             M
# 2     2020-01-01 2025-10-23 00:02:00          USA             M
# 3     2020-01-01 2025-10-23 00:03:00       Canada             M
# 4     2020-01-01 2025-10-23 00:04:00       Canada             M
# ...          ...                 ...          ...           ...
# 65533 2020-02-15 2025-10-23 12:13:00        India             F
# 65534 2020-02-15 2025-10-23 12:14:00       Canada             F
# 65535 2020-02-15 2025-10-23 12:15:00          USA             M
# 65536 2020-02-15 2025-10-23 12:16:00       Canada             F
# 65537 2020-02-15 2025-10-23 12:17:00          USA             F
#
#        driver_age_raw  driver_age driver_race     violation_raw violation  \
# 0                  59          19       Asian     Drunk Driving  Speeding
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
from datetime import datetime

# %%
import pandas as pd

# %%
# SQL Database Connection
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="ashu",
    auth_plugin='mysql_native_password'
)

# %%
#Create cursor
mycursor = mydb.cursor()

# %%
print("Connection successful!")
# Out:
# Connection successful!

# %%
#Create Database
mycursor.execute("CREATE DATABASE secure_check")

# %%
#USE Database
mycursor.execute("USE secure_check")

# %%
#Create Table
create_table_query = """ 
CREATE TABLE IF NOT EXISTS policelog (
    stop_date DATETIME,
    stop_time DATETIME,
    country_name VARCHAR(200),
    driver_gender VARCHAR(10),
    driver_age_raw INT,
    driver_age INT,
    driver_race VARCHAR(200),
    violation_raw VARCHAR(200),
    violation VARCHAR(200),
    search_conducted VARCHAR(200),
    search_type VARCHAR(200),
    stop_outcome VARCHAR(200),
    is_arrested BOOLEAN,
    stop_duration VARCHAR(200),
    drugs_related_stop BOOLEAN,
    vehicle_number VARCHAR(200)
)
"""

# %%
mycursor.execute(create_table_query)
print("Table created sucessfully")
# Out:
# Table created sucessfully

# %%
#SQL insert Query
insert_query = """
INSERT INTO policelog (
    stop_date, stop_time, country_name, driver_gender, driver_age_raw, driver_age,
    driver_race, violation_raw, violation, search_conducted, search_type,
    stop_outcome, is_arrested, stop_duration, drugs_related_stop, vehicle_number
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
#Process DataFrame 
df['stop_time'] = pd.to_datetime(df['stop_time'], errors='coerce').dt.time
df['stop_date'] = pd.to_datetime(df['stop_date'], errors='coerce')

# %%
# Insert each row 
for index, row in df.iterrows():
    stop_datetime = None
    if pd.notnull(row['stop_date']) and pd.notnull(row['stop_time']):
        stop_datetime = f"{row['stop_date'].strftime('%Y-%m-%d')} {row['stop_time'].strftime('%H:%M:%S')}"

    mycursor.execute(insert_query, (
        row['stop_date'].strftime('%Y-%m-%d %H:%M:%S') if pd.notnull(row['stop_date']) else None,
        stop_datetime,
        row['country_name'],
        row['driver_gender'],
        row['driver_age_raw'],
        row['driver_age'],
        row['driver_race'],
        row['violation_raw'],
        row['violation'],
        row['search_conducted'],
        row['search_type'],
        row['stop_outcome'],
        row['is_arrested'],
        row['stop_duration'],
        row['drugs_related_stop'],
        row['vehicle_number']
    ))

# %%
# Commit Changes
mydb.commit()
print("All records inserted successfully!")
# Out:
# All records inserted successfully!

# %%
# Close Connection
mycursor.close()
mydb.close()
